# %% [markdown]
# <a href="https://colab.research.google.com/github/robertacristinaabreu01/IMDd_projetoIA/blob/main/C%C3%B3pia_de_IMDb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/RobertaAb/covid-16-junho-DATASUS/blob/master/An%C3%A1lise%20de%20Dados%20DATASUS%2016-junho-2020.ipynb
#
# https://www.youtube.com/watch?v=8vKvsLTLDzs

# %%
# !pip install --upgrade gspread
# Out:
# Requirement already up-to-date: gspread in /usr/local/lib/python3.7/dist-packages (3.7.0)
# ...

# %%
#importar o google sheet##
from google.colab import auth #import google drive e autenticação
auth.authenticate_user() #autenticação do usuário

import gspread #google sheet module
from oauth2client.client import GoogleCredentials #credenciais google

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
spreasheet = gc.open('imdb_top_1000')

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
page = spreasheet.sheet1

# %%
page.col_values(1)
#valores da 1°coluna
# Out:
# ['Poster_Link',
#  'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY98_CR1,0,67,98_AL_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UX67_CR0,0,67,98_AL_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY98_CR1,0,67,98_AL_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX67_CR0,0,67,98_AL_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNzA5ZDNlZWMtM2NhNS00NDJjLTk4NDItYTRmY2EwMWZlMTY3XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg',
# ...

# %%
page.row_values(1)
#informações da 1°linha (itens)
# Out:
# ['Poster_Link',
#  'Series_Title',
#  'Released_Year',
#  'Certificate',
#  'Runtime',
#  'Genre',
#  'IMDB_Rating',
#  'Overview',
#  'Meta_score',
#  'Director',
#  'Star1',
#  'Star2',
#  'Star3',
#  'Star4',
#  'No_of_Votes',
#  'Gross',
#  '',
#  'MATERIAL PARA AULA DE IA - FATEC 1°SEMESTRE/2021']

# %%
page.acell('A1').value
#informações da 1°célula
# Out:
# 'Poster_Link'

# %%
page.acell("F1").value
# Out:
# 'Genre'

# %%
page.cell(1,5).value
#informações da 1°linha na coluna 5
# Out:
# 'Runtime'

# %%
page.cell(2,6).value
#informações da 2 linha na coluna 6
# Out:
# 'Drama'

# %%
import pandas as pd

# %%
imdb_top_1000 = pd.DataFrame(page.get_all_records())

# %%
imdb_top_1000.head()
# Out:
#                                          Poster_Link  ... MATERIAL PARA AULA DE IA - FATEC 1°SEMESTRE/2021
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...  ...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...  ...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...  ...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...  ...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...  ...
#
# [5 rows x 18 columns]

# %%
imdb_top_1000.query('Released_Year==2008')
#dados de 2008
# Out:
#                                            Poster_Link  ... MATERIAL PARA AULA DE IA - FATEC 1°SEMESTRE/2021
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...  ...
# 66   https://m.media-amazon.com/images/M/MV5BMjExMT...  ...
# 224  https://m.media-amazon.com/images/M/MV5BOTcwMz...  ...
# 225  https://m.media-amazon.com/images/M/MV5BMTc5NT...  ...
# 227  https://m.media-amazon.com/images/M/MV5BMTUzOT...  ...
# 351  https://m.media-amazon.com/images/M/MV5BNTFmMj...  ...
# 354  https://m.media-amazon.com/images/M/MV5BZmNjZW...  ...
# 487  https://m.media-amazon.com/images/M/MV5BOWM4NT...  ...
# 489  https://m.media-amazon.com/images/M/MV5BMTc5Mj...  ...
# 494  https://m.media-amazon.com/images/M/MV5BMTUwOG...  ...
# 502  https://m.media-amazon.com/images/M/MV5BMTczNT...  ...
# 608  https://m.media-amazon.com/images/M/MV5BY2ViOT...  ...
# 615  https://m.media-amazon.com/images/M/MV5BMTM4Nz...  ...
# 616  https://m.media-amazon.com/images/M/MV5BMTMzMT...  ...
# ...

# %%
imdb_top_1000.query('Released_Year==2008').info
# Out:
# <bound method DataFrame.info of                                            Poster_Link  ... MATERIAL PARA AULA DE IA - FATEC 1°SEMESTRE/2021
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...  ...
# 66   https://m.media-amazon.com/images/M/MV5BMjExMT...  ...
# 224  https://m.media-amazon.com/images/M/MV5BOTcwMz...  ...
# 225  https://m.media-amazon.com/images/M/MV5BMTc5NT...  ...
# 227  https://m.media-amazon.com/images/M/MV5BMTUzOT...  ...
# 351  https://m.media-amazon.com/images/M/MV5BNTFmMj...  ...
# 354  https://m.media-amazon.com/images/M/MV5BZmNjZW...  ...
# 487  https://m.media-amazon.com/images/M/MV5BOWM4NT...  ...
# 489  https://m.media-amazon.com/images/M/MV5BMTc5Mj...  ...
# 494  https://m.media-amazon.com/images/M/MV5BMTUwOG...  ...
# 502  https://m.media-amazon.com/images/M/MV5BMTczNT...  ...
# 608  https://m.media-amazon.com/images/M/MV5BY2ViOT...  ...
# 615  https://m.media-amazon.com/images/M/MV5BMTM4Nz...  ...
# ...

# %%
amostra2008 = imdb_top_1000.query('Released_Year==2008')

# %%
amostra2008.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 2 to 933
# Data columns (total 18 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Poster_Link                                       21 non-null     object
#  1   Series_Title                                      21 non-null     object
#  2   Released_Year                                     21 non-null     object
#  3   Certificate                                       21 non-null     object
#  4   Runtime                                           21 non-null     object
#  5   Genre                                             21 non-null     object
#  6   IMDB_Rating                                       21 non-null     float64
#  7   Overview                                          21 non-null     object
#  8   Meta_score                                        21 non-null     object
# ...

# %%
amostra2008.head()
# Out:
#                                            Poster_Link  ... MATERIAL PARA AULA DE IA - FATEC 1°SEMESTRE/2021
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...  ...
# 66   https://m.media-amazon.com/images/M/MV5BMjExMT...  ...
# 224  https://m.media-amazon.com/images/M/MV5BOTcwMz...  ...
# 225  https://m.media-amazon.com/images/M/MV5BMTc5NT...  ...
# 227  https://m.media-amazon.com/images/M/MV5BMTUzOT...  ...
#
# [5 rows x 18 columns]

# %%
gc.create('nova planilha')
# Out:
# <Spreadsheet 'nova planilha' id:1C1n6QPN_8ElwppoQE2DpZkAiGoWkx8SlspB2atBH1Ys>

# %%
imdb_top_1000 = gc.open('nova planilha')

# %%
imdb_top_1000.add_worksheet('nova planilha',933,18)
# Out:
# <Worksheet 'nova planilha' id:366612646>

# %%
imdb_top_1000_amostra2008.update([amostra2008.columns.values.tolist()] + amostra2008.values.tolist())

# %%
amostra2008.columns.values.tolist()

# %%
amostra2008.values.tolist()
#separou cada cadastro com seus respectivos dados individuais

# %%
import matplotlib.pyplot as plt

# %%
from pandas.tseries.offsets import *

# %%
# !pip install geopandas

# %%
import geopandas as gpd

# %%
amostra2008['Gross']
#valor total de lucro de todos os filmes

# %%
amostra2008['Star1']

# %%
amostra2008['Star2']
# Out:
# 2          Heath Ledger
# 66        Elissa Knight
# 224    Naseeruddin Shah
# 225            Bee Vang
# 227       Ryôko Hirosue
# 351           Simon Yam
# 354           Dev Patel
# 487    Lina Leandersson
# 489        Marisa Tomei
# 494     Brendan Gleeson
# 502     Gwyneth Paltrow
# 608         Jung-woo Ha
# 615        Maggie Grace
# 616       David Thewlis
# 628      Cate Blanchett
# 756          Matt Damon
# 757       Michael Sheen
# 759          Colm Feore
# 913       Frederick Lau
# 917      Rosario Dawson
# 933     Samantha Morton
# Name: Star2, dtype: object

# %%
amostra2008['Star3']

# %%
import matplotlib.pyplot
# %matplotlib inline

# %%
imdb_top_1000.plot()
amostra2008 = matplotlib.pyplot.title('Star1 x Gros')
amostra2008 = matplotlib.pyplot.ylabel('Gross')
amostra2008 = matplotlib.pyplot.xlabel('Star1')
amostra2008 = matplotlib.pyplot.show()

# %%
imdb_top_1000.plot()
amostra2008 = matplotlib.pyplot.title('Star2 x Star1')
amostra2008 = matplotlib.pyplot.ylabel('Star2')
amostra2008 = matplotlib.pyplot.xlabel('Star1')
amostra2008 = matplotlib.pyplot.show()

# %%
imdb_top_1000.plot()
amostra2008 = matplotlib.pyplot.title('Star1 x Star3')
amostra2008 = matplotlib.pyplot.ylabel('Start3')
amostra2008 = matplotlib.pyplot.xlabel('Star1')
amostra2008 = matplotlib.pyplot.show()

# %%
import yaml

# %%
import seaborn as sns

# %%
import numpy as np

# %%
import scipy

# %%
# !pip install mice
# Out:
# ...
#   Created wheel for mice: filename=mice-0.0.1a0-cp37-none-any.whl size=1045 sha256=5fc7b36271812663c0ac95cfb49669c5b0fc33cce0531e54e72ddd139830ae36
#   Stored in directory: /root/.cache/pip/wheels/6c/e7/4f/1b0c52cfdb6dc95dd0ba1459459f8e4ed33cab25eccdd78d65
# Successfully built mice
# ...

# %%
from google.colab.data_table import DataTable

# %%
imdb_top_1000 = pd.DataFrame(page.get_all_records())
print(imdb_top_1000)
# Out:
#                                            Poster_Link  ... MATERIAL PARA AULA DE IA - FATEC 1°SEMESTRE/2021
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...  ...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...  ...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...  ...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...  ...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...  ...
# ..                                                 ...  ...                                              ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...  ...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...  ...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...  ...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...  ...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...  ...
#
# [1000 rows x 18 columns]

# %%
imdb_top_1000.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross', '',
#        'MATERIAL PARA AULA DE IA - FATEC 1°SEMESTRE/2021'],
#       dtype='object')

# %%
imdb_top_1000.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
c = imdb_top_1000.groupby('No_of_Votes')
c = c.sum()
c = c.sort_values(['No_of_Votes'], ascending=False)
c.head(1)
# Out:
#              IMDB_Rating
# No_of_Votes
# 2343110              9.3

# %%
c = imdb_top_1000.groupby('Gross')
c = c.sum()
c = c.sort_values(['No_of_Votes'], ascending=False)
c.head(1)
# Out:
#        IMDB_Rating  No_of_Votes
# Gross
#             1345.4     11720276

# %%
imdb_top_1000[imdb_top_1000.IMDB_Rating > 9]
# Out:
#                                          Poster_Link  ... MATERIAL PARA AULA DE IA - FATEC 1°SEMESTRE/2021
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...  ...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...  ...
#
# [2 rows x 18 columns]

# %%
imdb_top_1000[imdb_top_1000.Released_Year == 2010]
# Out:
#                                            Poster_Link  ... MATERIAL PARA AULA DE IA - FATEC 1°SEMESTRE/2021
# 8    https://m.media-amazon.com/images/M/MV5BMjAxMz...  ...
# 90   https://m.media-amazon.com/images/M/MV5BMWE3MG...  ...
# 141  https://m.media-amazon.com/images/M/MV5BNzgxMz...  ...
# 145  https://m.media-amazon.com/images/M/MV5BYzhiND...  ...
# 151  https://m.media-amazon.com/images/M/MV5BMTgxOT...  ...
# 230  https://m.media-amazon.com/images/M/MV5BMjA5ND...  ...
# 345  https://m.media-amazon.com/images/M/MV5BMjEzMz...  ...
# 346  https://m.media-amazon.com/images/M/MV5BMzU5Mj...  ...
# 352  https://m.media-amazon.com/images/M/MV5BMTUyMT...  ...
# 355  https://m.media-amazon.com/images/M/MV5BNzY2Nz...  ...
# 601  https://m.media-amazon.com/images/M/MV5BYzM2OG...  ...
# 602  https://m.media-amazon.com/images/M/MV5BZjRmNj...  ...
# 605  https://m.media-amazon.com/images/M/MV5BMTgzMT...  ...
# 614  https://m.media-amazon.com/images/M/MV5BMTM0OD...  ...
# ...

# %%
imdb_top_1000[imdb_top_1000.Director == 'José Padilha']
# Out:
#                                            Poster_Link  ... MATERIAL PARA AULA DE IA - FATEC 1°SEMESTRE/2021
# 345  https://m.media-amazon.com/images/M/MV5BMjEzMz...  ...
# 356  https://m.media-amazon.com/images/M/MV5BYmI1OD...  ...
#
# [2 rows x 18 columns]

# %%
imdb_top_1000[imdb_top_1000.Director == 'Martin Scorsese']
# Out:
#                                            Poster_Link  ... MATERIAL PARA AULA DE IA - FATEC 1°SEMESTRE/2021
# 15   https://m.media-amazon.com/images/M/MV5BY2NkZj...  ...
# 37   https://m.media-amazon.com/images/M/MV5BMTI1MT...  ...
# 111  https://m.media-amazon.com/images/M/MV5BM2M1Mm...  ...
# 145  https://m.media-amazon.com/images/M/MV5BYzhiND...  ...
# 147  https://m.media-amazon.com/images/M/MV5BMjIxMj...  ...
# 165  https://m.media-amazon.com/images/M/MV5BMTcxOW...  ...
# 173  https://m.media-amazon.com/images/M/MV5BYjRmOD...  ...
# 484  https://m.media-amazon.com/images/M/MV5BMGUyM2...  ...
# 687  https://m.media-amazon.com/images/M/MV5BMTViNj...  ...
# 836  https://m.media-amazon.com/images/M/MV5BMTUxMj...  ...
#
# [10 rows x 18 columns]

# %%
imdb_top_1000.sort_values(by = "IMDB_Rating")
# Out:
#                                            Poster_Link  ... MATERIAL PARA AULA DE IA - FATEC 1°SEMESTRE/2021
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...  ...
# 908  https://m.media-amazon.com/images/M/MV5BMTMzNz...  ...
# 909  https://m.media-amazon.com/images/M/MV5BMjI2OD...  ...
# 910  https://m.media-amazon.com/images/M/MV5BMjAxOT...  ...
# 911  https://m.media-amazon.com/images/M/MV5BYmFmNj...  ...
# ..                                                 ...  ...                                              ...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...  ...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...  ...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...  ...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...  ...
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...  ...
#
# [1000 rows x 18 columns]

# %%
imdb_top_1000_IMDB_Rating = imdb_top_1000[imdb_top_1000.Director == "José Padilha"]

len(imdb_top_1000_IMDB_Rating)
# Out:
# 2

# %%
imdb_top_1000_IMDB_Rating = imdb_top_1000[imdb_top_1000.Director == "Martin Scorsese"]
len(imdb_top_1000_IMDB_Rating)
# Out:
# 10

# %%
imdb_top_1000_IMDB_Rating =  imdb_top_1000[(imdb_top_1000.IMDB_Rating > 8) & (imdb_top_1000.Star1 == 'Al Pacino')]
len(imdb_top_1000_IMDB_Rating)
# Out:
# 3

# %%
imdb_top_1000_IMDB_Rating =  imdb_top_1000[(imdb_top_1000.IMDB_Rating > 7) & (imdb_top_1000.Star1 == 'Leonardo DiCaprio')]
len(imdb_top_1000_IMDB_Rating)
# Out:
# 9

# %%
imdb_top_1000.Series_Title
# Out:
# 0      The Shawshank Redemption
# 1                 The Godfather
# 2               The Dark Knight
# 3        The Godfather: Part II
# 4                  12 Angry Men
#                  ...
# 995      Breakfast at Tiffany's
# 996                       Giant
# 997       From Here to Eternity
# 998                    Lifeboat
# 999                The 39 Steps
# Name: Series_Title, Length: 1000, dtype: object

# %%
imdb_top_1000[['IMDB_Rating','Gross']]
# Out:
#      IMDB_Rating        Gross
# 0            9.3   28,341,469
# 1            9.2  134,966,411
# 2            9.0  534,858,444
# 3            9.0   57,300,000
# 4            9.0    4,360,000
# ..           ...          ...
# 995          7.6
# 996          7.6
# 997          7.6   30,500,000
# 998          7.6
# 999          7.6
#
# [1000 rows x 2 columns]

# %%
imdb_top_1000[imdb_top_1000["IMDB_Rating"] > 7]
# Out:
#                                            Poster_Link  ... MATERIAL PARA AULA DE IA - FATEC 1°SEMESTRE/2021
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...  ...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...  ...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...  ...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...  ...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...  ...
# ..                                                 ...  ...                                              ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...  ...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...  ...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...  ...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...  ...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...  ...
#
# [1000 rows x 18 columns]

# %%
imdb_top_1000[(imdb_top_1000["IMDB_Rating"] == 9.3) | (imdb_top_1000["IMDB_Rating"] == 9)]
# Out:
#                                          Poster_Link  ... MATERIAL PARA AULA DE IA - FATEC 1°SEMESTRE/2021
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...  ...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...  ...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...  ...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...  ...
#
# [4 rows x 18 columns]

# %%
imdb_top_1000.groupby('Series_Title').Overview.describe()
# Out:
#                             count  ... freq
# Series_Title                       ...
# 300                             1  ...    1
# 1917                            1  ...    1
# (500) Days of Summer            1  ...    1
# 12 Angry Men                    1  ...    1
# 12 Years a Slave                1  ...    1
# ...                           ...  ...  ...
# Zootopia                        1  ...    1
# Zulu                            1  ...    1
# Zwartboek                       1  ...    1
# À bout de souffle               1  ...    1
# Ôkami kodomo no Ame to Yuki     1  ...    1
#
# [999 rows x 4 columns]

# %%
imdb_top_1000.groupby('Series_Title').IMDB_Rating.median()
# Out:
# Series_Title
# 300                            7.6
# 1917                           8.3
# (500) Days of Summer           7.7
# 12 Angry Men                   9.0
# 12 Years a Slave               8.1
#                               ...
# Zootopia                       8.0
# Zulu                           7.7
# Zwartboek                      7.7
# À bout de souffle              7.8
# Ôkami kodomo no Ame to Yuki    8.1
# Name: IMDB_Rating, Length: 999, dtype: float64

# %%
imdb_top_1000.groupby('Series_Title').IMDB_Rating.mean()
# Out:
# Series_Title
# 300                            7.6
# 1917                           8.3
# (500) Days of Summer           7.7
# 12 Angry Men                   9.0
# 12 Years a Slave               8.1
#                               ...
# Zootopia                       8.0
# Zulu                           7.7
# Zwartboek                      7.7
# À bout de souffle              7.8
# Ôkami kodomo no Ame to Yuki    8.1
# Name: IMDB_Rating, Length: 999, dtype: float64

# %%
imdb_top_1000.groupby('Genre').IMDB_Rating.agg(['min', 'max'])
# Out:
#                               min  max
# Genre
# Action, Adventure             7.7  8.4
# Action, Adventure, Biography  7.9  7.9
# Action, Adventure, Comedy     7.6  8.2
# Action, Adventure, Crime      7.6  7.6
# Action, Adventure, Drama      7.6  8.9
# ...                           ...  ...
# Mystery, Romance, Thriller    8.3  8.3
# Mystery, Sci-Fi, Thriller     7.6  8.0
# Mystery, Thriller             7.6  8.4
# Thriller                      7.8  7.8
# Western                       7.8  8.8
#
# [202 rows x 2 columns]

# %%
imdb_top_1000.groupby('Star1').No_of_Votes.agg(['min', 'max'])
# Out:
#                          min     max
# Star1
# Aamir Khan             49300  344445
# Aaron Taylor-Johnson  524081  524081
# Abhay Deol             28749   28749
# Abraham Attah          73964   73964
# Adam Driver           246644  246644
# ...                      ...     ...
# Zbigniew Zamachowski   64390   64390
# Zooey Deschanel       472242  472242
# Çetin Tekindor         78925   78925
# Éric Toledano         760360  760360
# Ömer Faruk Sorak       33592   33592
#
# [660 rows x 2 columns]

# %%
imdb_top_1000.groupby('IMDB_Rating').No_of_Votes.agg(['min', 'max'])
# Out:
#                  min      max
# IMDB_Rating
# 7.6            26337   732876
# 7.7            25198   769145
# 7.8            25229  1118998
# 7.9            26542   939644
# 8.0            26642  1260806
# 8.1            25088  1000639
# 8.2            26402  1308302
# 8.3            27793  1267869
# 8.4            28401  1516346
# 8.5           167839  1341460
# 8.6            42004  1512360
# 8.7           918088  1676426
# 8.8           688390  2067042
# 8.9          1213505  1826188
# 9.0           689845  2303232
# 9.2          1620367  1620367
# 9.3          2343110  2343110

# %%
imdb_top_1000.groupby('Released_Year').No_of_Votes.agg(['min', 'max'])
# Out:
#                   min     max
# Released_Year
# 1920            57428   57428
# 1921           113314  113314
# 1922            88794   88794
# 1924            41985   41985
# 1925            53054  101053
# ...               ...     ...
# 2017            25198  647884
# 2018            25344  834477
# 2019            27187  939252
# 2020            33931  159171
# PG             269197  269197
#
# [100 rows x 2 columns]

# %%
imdb_top_1000.groupby(['Series_Title', 'Director']).IMDB_Rating.mean()
# Out:
# Series_Title                 Director
# 300                          Zack Snyder        7.6
# 1917                         Sam Mendes         8.3
# (500) Days of Summer         Marc Webb          7.7
# 12 Angry Men                 Sidney Lumet       9.0
# 12 Years a Slave             Steve McQueen      8.1
#                                                ...
# Zootopia                     Byron Howard       8.0
# Zulu                         Cy Endfield        7.7
# Zwartboek                    Paul Verhoeven     7.7
# À bout de souffle            Jean-Luc Godard    7.8
# Ôkami kodomo no Ame to Yuki  Mamoru Hosoda      8.1
# Name: IMDB_Rating, Length: 1000, dtype: float64

# %%
imdb_top_1000.groupby(['Genre', 'Director']).size()
# Out:
# Genre                         Director
# Action, Adventure             Christopher Nolan    2
#                               Steven Spielberg     2
#                               Ted Kotcheff         1
# Action, Adventure, Biography  Werner Herzog        1
# Action, Adventure, Comedy     Clyde Bruckman       1
#                                                   ..
# Mystery, Thriller             Oriol Paulo          1
#                               Sujoy Ghosh          1
# Thriller                      Terence Young        1
# Western                       Clint Eastwood       1
#                               Sergio Leone         3
# Length: 912, dtype: int64

# %%
imdb_top_1000.groupby(['IMDB_Rating', 'Director']).size()
# Out:
# IMDB_Rating  Director
# 7.6          Alan Parker              1
#              Alejandro Amenábar       1
#              Alejandro G. Iñárritu    1
#              Alex Proyas              1
#              Alfonso Cuarón           1
#                                      ..
# 9.0          Christopher Nolan        1
#              Francis Ford Coppola     1
#              Sidney Lumet             1
# 9.2          Francis Ford Coppola     1
# 9.3          Frank Darabont           1
# Length: 882, dtype: int64

# %%
imdb_top_1000.groupby(['IMDB_Rating', 'Star1']).size()
# Out:
# IMDB_Rating  Star1
# 7.6          Aaron Taylor-Johnson    1
#              Al Pacino               1
#              Aleksey Serebryakov     1
#              Amy Poehler             1
#              Ansel Elgort            1
#                                     ..
# 9.0          Al Pacino               1
#              Christian Bale          1
#              Henry Fonda             1
# 9.2          Marlon Brando           1
# 9.3          Tim Robbins             1
# Length: 916, dtype: int64

# %%
for IMDB_Rating, Released_Year in imdb_top_1000.groupby([imdb_top_1000.Released_Year == 1970]):
  #print(Director)
  print(Released_Year)
  #print(Gross)
  print(IMDB_Rating)
# Out:
#                                            Poster_Link  ... MATERIAL PARA AULA DE IA - FATEC 1°SEMESTRE/2021
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...  ...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...  ...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...  ...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...  ...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...  ...
# ..                                                 ...  ...                                              ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...  ...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...  ...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...  ...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...  ...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...  ...
#
# [997 rows x 18 columns]
# False
#                                            Poster_Link  ... MATERIAL PARA AULA DE IA - FATEC 1°SEMESTRE/2021
# ...

# %%
imdb_top_1000.loc[imdb_top_1000.IMDB_Rating.isin([9.3, 9.0, 8.0]), ['Series_Title','Gross']]
# Out:
#                        Series_Title        Gross
# 0          The Shawshank Redemption   28,341,469
# 2                   The Dark Knight  534,858,444
# 3            The Godfather: Part II   57,300,000
# 4                      12 Angry Men    4,360,000
# 322                      Badhaai ho
# ..                              ...          ...
# 458                The Wizard of Oz    2,076,020
# 459                 La règle du jeu
# 460                    The Thin Man
# 461  All Quiet on the Western Front    3,270,000
# 462            Bronenosets Potemkin        50,97
#
# [145 rows x 2 columns]

# %%
imdb_top_1000.shape[0]
# Out:
# 1000
